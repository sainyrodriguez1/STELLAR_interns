# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from astropy.io import ascii 
import matplotlib.pyplot as plt
from astropy.table import Table

# %%
ourdata = pd.read_csv('data/measured_rps.csv')

# %%
ourdata
# Out:
#           tic     period
# 0   141526439  15.630803
# 1   141527965   4.747520
# 2   370235284   6.890970
# 3   177284607  11.428718
# 4   176872276   5.095760
# 5   295072161   6.436905
# 6   294750180   0.525536
# 7    25155612   8.078025
# 8   348896748   5.099362
# 9   281631603  10.254541
# 10  150437065  11.623358
# 11   38461375   7.057561
# 12  382517990   9.819882
# 13  349194688   6.693696
# 14   55498515  11.976158
# 15   38461205  35.995205
# 16  348898540   6.820247
# 17   38507842   7.723481
# 18   38510224   9.837096
# 19  167795767   6.230444
# 20   38678931   7.768626
# 21   55745883   7.209692
# 22   38586374  32.581667
# 23   38510271   2.931013
# 24  150189995   2.931013
# 25   55604374   6.919293
# 26  149497763   9.224421
# 27  220428553  11.400341
# 28  340007359  14.286633

# %%
our_tem = Table.read('data/Interns_tic_table.fits')

# %%
our_tem
# Out:
# <Table length=142>
#     ID    TOTsecs          rvar         ... raddflag wdflag   objID
#   int64    int64         float64        ...  int64   int64    int64
# --------- ------- --------------------- ... -------- ------ ---------
# 140596802      12   0.00884114503860478 ...        1      0 526088389
# 140662908      12  0.009300917387008667 ...        1      0 528602588
# 140893722      12   0.00863834619522097 ...        1      0 534742954
# 140943185      12  0.005686497688293435 ...        1      0 536249184
# 140971842      12  0.009916543960571289 ...       -1     -1 535709841
# 141480434      13 0.0067489296197891235 ...        1      0 552000119
# 141526439      12  0.009427249431610107 ...        1      0 552823294
# 141527965      12  0.007911312580108687 ...        1      0 552648203
# 141542585      12   0.00571026206016545 ...       -1      0 554867528
# 141623174      12  0.004150032997131348 ...        1      0 555790592
#       ...     ...                   ... ...      ...    ...       ...
# 391947345      13  0.013665586709976196 ...        1      0 585015759
#  40601527      12  0.007225042581558316 ...        1      0 535381329
#  55367248      11  0.007152128219604426 ...        1      0 536355143
#  55452078      11  0.004177469015121504 ...        1      0 526943387
#  55498515      11  0.008318382501602106 ...        1      0 527546471
#  55604374      13  0.009815558791160583 ...        1      0 529180641
#  55652063      12  0.007324054837226757 ...        1      0 529622113
#  55745883      12  0.003914129734039151 ...        1      0 531207371
#  55745991      12  0.008114194869994984 ...        1      0 530434279
#  55758201      12  0.004180604219436779 ...        1      0 532497147

# %%
our_tics =[]
our_temps = []
our_gaiabp = []
our_gaiarp = []
#count = 0 
for row in our_tem:
    tic = row['ID'] 
    temp = row['Teff']
    bp = row['gaiabp']
    rp = row['gaiarp']
    outtics = ourdata['tic'].values
    if tic in outtics:
        our_tics.append(tic)
        our_temps.append(temp)
        our_gaiabp.append(bp)
        our_gaiarp.append(rp)
        
    else:
        pass

# %%
data_to_add = {'tic': our_tics, 'temp': our_temps, 'bp': our_gaiabp, 'rp': our_gaiarp}
df_to_add = pd.DataFrame(data = data_to_add)
df_to_add
# Out:
#           tic    temp       bp        rp
# 0   141526439  3624.0  13.9832  11.79620
# 1   141527965  4280.0  13.1119  11.48570
# 2   149497763  3736.0  13.4823  11.44160
# 3   150189995  4380.0  12.8811  11.37250
# 4   150437065  4013.0  13.0292  11.25390
# 5   167795767  4165.0  13.4372  11.70860
# 6   176872276  4290.0  13.2311  11.49990
# 7   177284607  4466.0  12.5355  11.15150
# 8   220428553  3732.0      NaN       NaN
# 9    25155612  4241.0      NaN       NaN
# 10  281631603  3837.0  13.4835  11.55630
# 11  294750180  3590.0      NaN       NaN
# 12  295072161  4470.0  11.4700   9.99030
# 13  340007359  3920.0  12.5302  10.68680
# 14  348896748  4265.0  13.4999  11.77040
# 15  348898540  4442.0  13.4018  11.97530
# 16  349194688  4420.3  11.0280   9.69599
# 17  370235284  4255.0  13.0550  11.32910
# 18  382517990  4405.0      NaN       NaN
# 19   38461205  3673.0  13.9459  11.82600
# 20   38461375  3602.0  14.1382  11.91990
# 21   38507842  4137.3      NaN       NaN
# 22   38510224  4356.0  13.1507  11.69170
# 23   38510271  3578.0  13.8222  11.56770
# 24   38586374  4457.0  13.1440  11.76650
# 25   38678931  4396.0  13.4481  12.08420
# 26   55498515  3416.0  14.1066  11.57670
# 27   55604374  3849.0  13.7606  11.84580
# 28   55745883  3418.0  12.7870  10.26050

# %%
ourdata_withtemp = ourdata.merge(df_to_add, sort = True, on ='tic') 
ourdata_withtemp
# Out:
#           tic     period    temp       bp        rp
# 0    25155612   8.078025  4241.0      NaN       NaN
# 1    38461205  35.995205  3673.0  13.9459  11.82600
# 2    38461375   7.057561  3602.0  14.1382  11.91990
# 3    38507842   7.723481  4137.3      NaN       NaN
# 4    38510224   9.837096  4356.0  13.1507  11.69170
# 5    38510271   2.931013  3578.0  13.8222  11.56770
# 6    38586374  32.581667  4457.0  13.1440  11.76650
# 7    38678931   7.768626  4396.0  13.4481  12.08420
# 8    55498515  11.976158  3416.0  14.1066  11.57670
# 9    55604374   6.919293  3849.0  13.7606  11.84580
# 10   55745883   7.209692  3418.0  12.7870  10.26050
# 11  141526439  15.630803  3624.0  13.9832  11.79620
# 12  141527965   4.747520  4280.0  13.1119  11.48570
# 13  149497763   9.224421  3736.0  13.4823  11.44160
# 14  150189995   2.931013  4380.0  12.8811  11.37250
# 15  150437065  11.623358  4013.0  13.0292  11.25390
# 16  167795767   6.230444  4165.0  13.4372  11.70860
# 17  176872276   5.095760  4290.0  13.2311  11.49990
# 18  177284607  11.428718  4466.0  12.5355  11.15150
# 19  220428553  11.400341  3732.0      NaN       NaN
# 20  281631603  10.254541  3837.0  13.4835  11.55630
# 21  294750180   0.525536  3590.0      NaN       NaN
# 22  295072161   6.436905  4470.0  11.4700   9.99030
# 23  340007359  14.286633  3920.0  12.5302  10.68680
# 24  348896748   5.099362  4265.0  13.4999  11.77040
# 25  348898540   6.820247  4442.0  13.4018  11.97530
# 26  349194688   6.693696  4420.3  11.0280   9.69599
# 27  370235284   6.890970  4255.0  13.0550  11.32910
# 28  382517990   9.819882  4405.0      NaN       NaN

# %%
keplerdata = pd.read_csv('data/Table_1_Periodic.txt', header=0)

# %%
keplerdata
# Out:
#             KID  Teff  logg    Mass    Prot  Prot_err      Rper    LPH  \
# 0        892376  3813  4.47  0.4699   1.532     0.007   7306.69  0.823
# 1       1026146  4261  4.57  0.6472  14.891     0.120  11742.56  1.405
# 2       1026474  4122  4.56  0.5914   1.569     0.006  30471.80  1.204
# 3       1162635  3760  4.77  0.4497  15.678     0.019  10207.47  0.978
# 4       1164102  4045  4.62  0.5606  31.496     0.474   5139.74  0.568
# ...         ...   ...   ...     ...     ...       ...       ...    ...
# 34025  12934465  4714  4.88  0.7591  34.910     1.692   4572.33  0.433
# 34026  12934525  5278  4.72  0.9062  25.101     0.240   5150.14  0.573
# 34027  12934557  5341  4.58  0.9227  31.226     0.729   1889.88  0.401
# 34028  12984138  4960  4.57  0.8239  12.059     0.038  11734.90  1.194
# 34029  12984214  5267  3.82  0.9034   7.566     0.010   3887.65  1.003
#
#             w  DC Flag
# 0      0.4503   0  ---
# 1      0.7229   0  ---
# 2      0.6061   0  ---
# 3      0.5445   1  ---
# 4      0.3939   0  ---
# ...       ...  ..  ...
# 34025  0.2969   0  ---
# 34026  0.4144   0  ---
# 34027  0.2511   0  ---
# 34028  0.6442   0  ---
# 34029  0.5465   0  ---
#
# [34030 rows x 11 columns]

# %%
rot_1 = ourdata_withtemp['period']
temp_1 = ourdata_withtemp['temp']
rot_2 = keplerdata['Prot']
temp_2 = keplerdata['Teff']

plt.figure(figsize=(10,5))
plt.scatter(temp_1,rot_1, s=20, zorder = 0, c = 'maroon')
plt.scatter(temp_2,rot_2, s=.5, zorder = 1, c = 'grey')
plt.xlabel(' Temperature', fontsize = 25)
plt.ylabel('Rotation Period', fontsize = 25) 
#plt.legend()
plt.xlim(6500,3000)
plt.title('Comparing Kepler RPS to Tess RPs', c = 'navy', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Comparing Kepler RPS to Tess RPs')

# %%
def age_model(log10_period, bprp):
    """
    Predicts log10 age from log10 color and log10 period.
    Args:
        log10_period (array): The (log10) period array.
        log10_bprp (array): The (log10) G_bp - G_rp color array.
    Returns:
        log10_age (array): The (log10) age  array.
    """
    # If star is very hot, return the age of the Universe.
    # Don't try to take the log of a negative number.
    if bprp < 0:
        return 10.14

    log10_bprp = np.log10(bprp)

    # Hard-code the gyro parameters :-)
    p = [-38.957586198640314, 28.709418579540294, -4.919056437046026,
        0.7161114835620975, -4.716819674578521, 0.6470950862322454,
        -13.558898318835137, 0.9359250478865809]

    # p = [-38.982347111370984, 28.706848179526098, -4.922906414784183,
    #      0.7176636876966253, -5.489008990829778, 0.7347258099244045,
    #      -13.55785651951684, 0.16105197784241776]

    if log10_bprp >= .43:
        # return (log10_period - np.polyval(p[6:], log10_bprp))/p[5]
        return 10.14  # The age of the universe
    elif log10_bprp < -.25:
        return 10.14
    else:
        logage = (log10_period - np.polyval(p[:5], log10_bprp))/p[5]
        return logage

# %%
bprp = .82  # Gaia BP - RP color.
log10_period = np.log10(26)
log10_age_yrs = age_model(log10_period, bprp)
print((10**log10_age_yrs)*1e-9, "Gyr")
# Out:
# 4.565055357152765 Gyr

# %%
ages = [] 
for row in ourdata_withtemp.values: 
#     print(row)
#     print(row[0])
#     break
    tic = row[0]
    period = row[1]
    bp = row [3]
    rp = row [4]
    if np.isnan(bp) == False: 
        bprp = bp - rp 
        log10_period = np.log10(period) 
        log10_age_yrs = age_model(log10_period, bprp)
        print("TIC: ", tic,"age is", (10**log10_age_yrs)*1e-9, "Gyr") 
        age = (10**log10_age_yrs)*1e-9 
        ages.append(age) 
    else:
        print("No color data-can't get age")
        age = -9999 
        ages.append(age)
# Out:
# No color data-can't get age
# TIC:  38461205.0 age is 1.921071706356266 Gyr
# TIC:  38461375.0 age is 0.14220384485432816 Gyr
# No color data-can't get age
# TIC:  38510224.0 age is 0.49467698207478 Gyr
# TIC:  38510271.0 age is 0.03553871791452343 Gyr
# TIC:  38586374.0 age is 3.3389414334576646 Gyr
# TIC:  38678931.0 age is 0.367540978126827 Gyr
# TIC:  55498515.0 age is 0.2680950577003562 Gyr
# TIC:  55604374.0 age is 0.18424737255088938 Gyr
# TIC:  55745883.0 age is 0.12251203251248804 Gyr
# TIC:  141526439.0 age is 0.4987498262282755 Gyr
# TIC:  141527965.0 age is 0.1386205186944955 Gyr
# TIC:  149497763.0 age is 0.25268877932963973 Gyr
# TIC:  150189995.0 age is 0.0731646217124229 Gyr
# TIC:  150437065.0 age is 0.47565680626957013 Gyr
# TIC:  167795767.0 age is 0.190479173131703 Gyr
# TIC:  176872276.0 age is 0.1392383274800936 Gyr
# TIC:  177284607.0 age is 0.6585799855473927 Gyr
# No color data-can't get age
# TIC:  281631603.0 age is 0.33404757209512603 Gyr
# No color data-can't get age
# TIC:  295072161.0 age is 0.2526901904145871 Gyr
# TIC:  340007359.0 age is 0.6090177966766254 Gyr
# TIC:  348896748.0 age is 0.13963468833779397 Gyr
# TIC:  348898540.0 age is 0.2878374594575094 Gyr
# TIC:  349194688.0 age is 0.2979000425717158 Gyr
# TIC:  370235284.0 age is 0.2231931351702198 Gyr
# No color data-can't get age

# %%
mytest = [5]
np.isnan(mytest)
# Out:
# array([False])

# %%
ourdata_withtemp['Age_in_Gyr'] = ages

# %%
ourdata_withtemp
# Out:
#           tic     period    temp       bp        rp         ages   Age_in_Gyr
# 0    25155612   8.078025  4241.0      NaN       NaN -9999.000000 -9999.000000
# 1    38461205  35.995205  3673.0  13.9459  11.82600     1.921072     1.921072
# 2    38461375   7.057561  3602.0  14.1382  11.91990     0.142204     0.142204
# 3    38507842   7.723481  4137.3      NaN       NaN -9999.000000 -9999.000000
# 4    38510224   9.837096  4356.0  13.1507  11.69170     0.494677     0.494677
# 5    38510271   2.931013  3578.0  13.8222  11.56770     0.035539     0.035539
# 6    38586374  32.581667  4457.0  13.1440  11.76650     3.338941     3.338941
# 7    38678931   7.768626  4396.0  13.4481  12.08420     0.367541     0.367541
# 8    55498515  11.976158  3416.0  14.1066  11.57670     0.268095     0.268095
# 9    55604374   6.919293  3849.0  13.7606  11.84580     0.184247     0.184247
# 10   55745883   7.209692  3418.0  12.7870  10.26050     0.122512     0.122512
# 11  141526439  15.630803  3624.0  13.9832  11.79620     0.498750     0.498750
# 12  141527965   4.747520  4280.0  13.1119  11.48570     0.138621     0.138621
# 13  149497763   9.224421  3736.0  13.4823  11.44160     0.252689     0.252689
# 14  150189995   2.931013  4380.0  12.8811  11.37250     0.073165     0.073165
# 15  150437065  11.623358  4013.0  13.0292  11.25390     0.475657     0.475657
# 16  167795767   6.230444  4165.0  13.4372  11.70860     0.190479     0.190479
# 17  176872276   5.095760  4290.0  13.2311  11.49990     0.139238     0.139238
# 18  177284607  11.428718  4466.0  12.5355  11.15150     0.658580     0.658580
# 19  220428553  11.400341  3732.0      NaN       NaN -9999.000000 -9999.000000
# 20  281631603  10.254541  3837.0  13.4835  11.55630     0.334048     0.334048
# 21  294750180   0.525536  3590.0      NaN       NaN -9999.000000 -9999.000000
# 22  295072161   6.436905  4470.0  11.4700   9.99030     0.252690     0.252690
# 23  340007359  14.286633  3920.0  12.5302  10.68680     0.609018     0.609018
# 24  348896748   5.099362  4265.0  13.4999  11.77040     0.139635     0.139635
# 25  348898540   6.820247  4442.0  13.4018  11.97530     0.287837     0.287837
# 26  349194688   6.693696  4420.3  11.0280   9.69599     0.297900     0.297900
# 27  370235284   6.890970  4255.0  13.0550  11.32910     0.223193     0.223193
# 28  382517990   9.819882  4405.0      NaN       NaN -9999.000000 -9999.000000

# %%
plt.figure(figsize=(10,5),dpi=200)
plt.scatter(ourdata_withtemp['Age_in_Gyr'],ourdata_withtemp['period'],s=5)
plt.ylabel('Rotation Period (days)',fontsize=15)
plt.xlabel('Age (Gyr)',fontsize=15)
plt.xlim(-0.5,4);
print('what trend does this show?')
# Out:
# what trend does this show?
