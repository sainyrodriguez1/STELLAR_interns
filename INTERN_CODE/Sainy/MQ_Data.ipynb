# %%
# %matplotlib inline 
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
path1 = open('data/Table_1_Periodic.txt','r')
path2 = open('data/Table_2_Non_Periodic.txt', 'r')

# %%
path1_header = path1.readline() 
path1_header
# Out:
# 'KID,Teff,logg,Mass,Prot,Prot_err,Rper,LPH,w,DC,Flag\n'

# %%
table1 = pd.read_csv('data/Table_1_Periodic.txt')
table1
# Out:
#             KID  Teff  logg    Mass    Prot  Prot_err      Rper    LPH  \
# 0        892376  3813  4.47  0.4699   1.532     0.007   7306.69  0.823
# 1       1026146  4261  4.57  0.6472  14.891     0.120  11742.56  1.405
# 2       1026474  4122  4.56  0.5914   1.569     0.006  30471.80  1.204
# 3       1162635  3760  4.77  0.4497  15.678     0.019  10207.47  0.978
# 4       1164102  4045  4.62  0.5606  31.496     0.474   5139.74  0.568
# ...         ...   ...   ...     ...     ...       ...       ...    ...
# 34025  12934465  4714  4.88  0.7591  34.910     1.692   4572.33  0.433
# 34026  12934525  5278  4.72  0.9062  25.101     0.240   5150.14  0.573
# 34027  12934557  5341  4.58  0.9227  31.226     0.729   1889.88  0.401
# 34028  12984138  4960  4.57  0.8239  12.059     0.038  11734.90  1.194
# 34029  12984214  5267  3.82  0.9034   7.566     0.010   3887.65  1.003
#
#             w  DC Flag
# 0      0.4503   0  ---
# 1      0.7229   0  ---
# 2      0.6061   0  ---
# ...

# %%
table2 = pd.read_csv('data/Table_2_Non_Periodic.txt')
table2
# Out:
#             KID  Teff  logg    Mass    Prot  Prot_err    LPH       w  DC
# 0        893305  4133  4.58  0.5958     NaN       NaN    NaN     NaN   0
# 1       1027110  4155  4.50  0.6046   1.701     0.039  0.299  0.1439   0
# 2       1027277  4326  4.57  0.6735  60.136     0.691  0.315  0.0876   0
# 3       1160660  4232  4.59  0.6355     NaN       NaN    NaN     NaN   0
# 4       1160684  3952  4.48  0.5239   0.419     0.090  0.150  0.0266   0
# ...         ...   ...   ...     ...     ...       ...    ...     ...  ..
# 98995  12935010  4776  4.40  0.7756  29.986     3.730  0.269  0.1523   0
# 98996  12935127  4769  4.56  0.7737     NaN       NaN    NaN     NaN   0
# 98997  12984183  5176  4.49  0.8798  24.754     1.705  0.285  0.1650   0
# 98998  12984200  5621  4.46  0.9975     NaN       NaN    NaN     NaN   0
# 98999  12984422  5078  4.57  0.8545     NaN       NaN    NaN     NaN   0
#
# [99000 rows x 9 columns]

# %% [markdown]
# PLOTTING THE GRAPHS!

# %%
tem_1 = table1['Teff'] 
rot_1 = table1['Prot'] 
tem_2 = table2['Teff'] 
rot_2 = table2['Prot'] 
plt.figure(figsize=(14.5,10))
plt.scatter(tem_1,rot_1, s=3, c = 'maroon', label = 'Periotic')
plt.scatter(tem_2,rot_2, s=3, c = 'gold',label ='Non_Periotic') 
plt.xlabel('Effective Temperature', fontsize = 25)
plt.ylabel('Rotation Period', fontsize = 25) 
plt.legend()
plt.xlim(6500,3500)
plt.title('Stellar Rotation Period', c = 'navy', fontsize = 30)
# Out:
# Text(0.5, 1.0, 'Stellar Rotation Period')

# %%
table1 = table1.dropna()
table2 = table2.dropna() 
len(table1), len(table2)
# Out:
# (34030, 30754)

# %%
table_1_ar = np.repeat(1,len(table1)) 
print(table_1_ar)
# Out:
# [1 1 1 ... 1 1 1]

# %%
table_2_ar = np.repeat(0,len(table2))
print(table_2_ar)
# Out:
# [0 0 0 ... 0 0 0]

# %%
classes = np.append(table_1_ar, table_2_ar  )
print(classes)
# Out:
# [1 1 1 ... 0 0 0]

# %%
tables = pd.concat([table1, table2], axis=0, sort=True)# sort gives it new indices
tables = tables.drop(columns=['Flag', 'Rper'])
tables
# Out:
#        DC       KID    LPH    Mass    Prot  Prot_err  Teff  logg       w
# 0       0    892376  0.823  0.4699   1.532     0.007  3813  4.47  0.4503
# 1       0   1026146  1.405  0.6472  14.891     0.120  4261  4.57  0.7229
# 2       0   1026474  1.204  0.5914   1.569     0.006  4122  4.56  0.6061
# 3       1   1162635  0.978  0.4497  15.678     0.019  3760  4.77  0.5445
# 4       0   1164102  0.568  0.5606  31.496     0.474  4045  4.62  0.3939
# ...    ..       ...    ...     ...     ...       ...   ...   ...     ...
# 98982   0  12934488  0.507  1.0281  51.754     0.849  5731  4.59  0.2247
# 98991   0  12934771  0.117  0.8275  60.106     4.700  4974  3.91  0.0081
# 98994   0  12934955  0.525  1.0680  57.268     6.512  5870  4.51  0.2272
# 98995   0  12935010  0.269  0.7756  29.986     3.730  4776  4.40  0.1523
# 98997   0  12984183  0.285  0.8798  24.754     1.705  5176  4.49  0.1650
#
# [64784 rows x 9 columns]

# %%
tables['class'] = classes
# type(tables)
tables
# Out:
#        DC       KID    LPH    Mass    Prot  Prot_err  Teff  logg       w  \
# 0       0    892376  0.823  0.4699   1.532     0.007  3813  4.47  0.4503
# 1       0   1026146  1.405  0.6472  14.891     0.120  4261  4.57  0.7229
# 2       0   1026474  1.204  0.5914   1.569     0.006  4122  4.56  0.6061
# 3       1   1162635  0.978  0.4497  15.678     0.019  3760  4.77  0.5445
# 4       0   1164102  0.568  0.5606  31.496     0.474  4045  4.62  0.3939
# ...    ..       ...    ...     ...     ...       ...   ...   ...     ...
# 98982   0  12934488  0.507  1.0281  51.754     0.849  5731  4.59  0.2247
# 98991   0  12934771  0.117  0.8275  60.106     4.700  4974  3.91  0.0081
# 98994   0  12934955  0.525  1.0680  57.268     6.512  5870  4.51  0.2272
# 98995   0  12935010  0.269  0.7756  29.986     3.730  4776  4.40  0.1523
# 98997   0  12984183  0.285  0.8798  24.754     1.705  5176  4.49  0.1650
#
#        class
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...

# %%
plt.figure(figsize=(14,8))
plt.scatter(tables['Teff'],tables['Prot'],s=.2, c =tables['class'], vmin=0,vmax=1)
plt.colorbar().set_label('Class',fontsize=20)
plt.xlabel('Effective Temperature', fontsize = 25)
plt.ylabel('Rotation Period', fontsize = 25) 
plt.legend()
plt.xlim(6500,3500)
plt.title('Decision Tree Sample of Stellar Rotation Period', c = 'navy', fontsize = 30)
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'Decision Tree Sample of Stellar Rotation Period')

# %%
tables = tables.drop(columns=['class'])
tables
# Out:
#        DC       KID    LPH    Mass    Prot  Prot_err  Teff  logg       w
# 0       0    892376  0.823  0.4699   1.532     0.007  3813  4.47  0.4503
# 1       0   1026146  1.405  0.6472  14.891     0.120  4261  4.57  0.7229
# 2       0   1026474  1.204  0.5914   1.569     0.006  4122  4.56  0.6061
# 3       1   1162635  0.978  0.4497  15.678     0.019  3760  4.77  0.5445
# 4       0   1164102  0.568  0.5606  31.496     0.474  4045  4.62  0.3939
# ...    ..       ...    ...     ...     ...       ...   ...   ...     ...
# 98982   0  12934488  0.507  1.0281  51.754     0.849  5731  4.59  0.2247
# 98991   0  12934771  0.117  0.8275  60.106     4.700  4974  3.91  0.0081
# 98994   0  12934955  0.525  1.0680  57.268     6.512  5870  4.51  0.2272
# 98995   0  12935010  0.269  0.7756  29.986     3.730  4776  4.40  0.1523
# 98997   0  12984183  0.285  0.8798  24.754     1.705  5176  4.49  0.1650
#
# [64784 rows x 9 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X = tables 
y = classes

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y, random_state = 11)
model = DecisionTreeClassifier()
#fit the model to the training set
fit_model = model.fit(train_X,train_y)
#compare predictions from this model to the test set
predicted = fit_model.predict(test_X)
accuracy_score(test_y, predicted)
# Out:
# 0.999938256359595

# %%
from sklearn import tree
plt.figure(figsize= (20,15))
tree.plot_tree(model.fit(test_X,test_y));

# %%
tables = tables.drop(columns=['w'])
tables
# Out:
#        DC       KID    LPH    Mass    Prot  Prot_err  Teff  logg
# 0       0    892376  0.823  0.4699   1.532     0.007  3813  4.47
# 1       0   1026146  1.405  0.6472  14.891     0.120  4261  4.57
# 2       0   1026474  1.204  0.5914   1.569     0.006  4122  4.56
# 3       1   1162635  0.978  0.4497  15.678     0.019  3760  4.77
# 4       0   1164102  0.568  0.5606  31.496     0.474  4045  4.62
# ...    ..       ...    ...     ...     ...       ...   ...   ...
# 98982   0  12934488  0.507  1.0281  51.754     0.849  5731  4.59
# 98991   0  12934771  0.117  0.8275  60.106     4.700  4974  3.91
# 98994   0  12934955  0.525  1.0680  57.268     6.512  5870  4.51
# 98995   0  12935010  0.269  0.7756  29.986     3.730  4776  4.40
# 98997   0  12984183  0.285  0.8798  24.754     1.705  5176  4.49
#
# [64784 rows x 8 columns]

# %%
X2 = tables
train_X, test_X, train_y, test_y = train_test_split(X2, y, random_state = 11)
model = DecisionTreeClassifier()
#fit the model to the training set
fit_model = model.fit(train_X,train_y)
#compare predictions from this model to the test set
predicted = fit_model.predict(test_X)
accuracy_score(test_y, predicted)
# Out:
# 0.9848728081007656

# %%
#print(X)
# Out:
#        DC       KID    LPH    Mass    Prot  Prot_err  Teff  logg       w
# 0       0    892376  0.823  0.4699   1.532     0.007  3813  4.47  0.4503
# 1       0   1026146  1.405  0.6472  14.891     0.120  4261  4.57  0.7229
# 2       0   1026474  1.204  0.5914   1.569     0.006  4122  4.56  0.6061
# 3       1   1162635  0.978  0.4497  15.678     0.019  3760  4.77  0.5445
# 4       0   1164102  0.568  0.5606  31.496     0.474  4045  4.62  0.3939
# ...    ..       ...    ...     ...     ...       ...   ...   ...     ...
# 98982   0  12934488  0.507  1.0281  51.754     0.849  5731  4.59  0.2247
# 98991   0  12934771  0.117  0.8275  60.106     4.700  4974  3.91  0.0081
# 98994   0  12934955  0.525  1.0680  57.268     6.512  5870  4.51  0.2272
# 98995   0  12935010  0.269  0.7756  29.986     3.730  4776  4.40  0.1523
# 98997   0  12984183  0.285  0.8798  24.754     1.705  5176  4.49  0.1650
#
# [64784 rows x 9 columns]

# %%
from sklearn import tree
plt.figure(figsize= (20,15))
tree.plot_tree(model.fit(test_X,test_y));
